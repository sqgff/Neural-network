# %%
from rbm import RBM
from dbn import DeepBeliefNetwork
from autoencoder_rbm import Autoencoder_RBM
import numpy as np
import tensorflow as tf

from tensorflow.examples.tutorials.mnist import input_data

# Download the data in the working directory
mnist = input_data.read_data_sets("../data/mnist/", one_hot=True)

#training_data = {image: mnist.train.images, label: mnist.train.labels}
#validation_data = {image: mnist.validation.images, label: mnist.validation.labels}
#test_data = {image: mnist.test.images, label: mnist.test.labels}
train_dataset = mnist.train.images
train_labels = mnist.train.labels
validation_dataset = mnist.validation.images
validation_labels = mnist.validation.labels
test_dataset = mnist.test.images
test_labels = mnist.test.labels
print("The shape of the dataset for training: ", train_dataset.shape, train_labels.shape)
print("The shape of the dataset for validation: ", validation_dataset.shape, validation_labels.shape)
print("The shape of the dataset for test: ", test_dataset.shape, test_labels.shape)

# Test for RBM
#rbm_model = RBM(visible_unit_type='gauss', batch_size=100, n_epochs=3, learning_rate=0.01)
#rbm_model.fit(train_dataset, validation_set = validation_dataset)
#rbm_model.get_parameters(tf.Graph())
#print(rbm_model.trained_params)

# Test for DBN
#"""
# Out:
# Extracting ../data/mnist/train-images-idx3-ubyte.gz
# Extracting ../data/mnist/train-labels-idx1-ubyte.gz
# Extracting ../data/mnist/t10k-images-idx3-ubyte.gz
# Extracting ../data/mnist/t10k-labels-idx1-ubyte.gz
# The shape of the dataset for training:  (55000, 784) (55000, 10)
# The shape of the dataset for validation:  (5000, 784) (5000, 10)
# The shape of the dataset for test:  (10000, 784) (10000, 10)

# %%
dbn_model_1 = DeepBeliefNetwork(
        name='dbn',
        rbm_layers=[800, 400, 80],
        rbm_gauss_visible=True,
        finetune_num_epochs=80,
        do_pretrain=False)
accuracy_summary_1, loss_summary_1 = dbn_model_1.fit(train_dataset, train_labels, validation_dataset, validation_labels, test_dataset, test_labels)
# Out:
# Iter 1:  Training: current loss 1.519474 | current accuracy 0.557727 || Validation: current loss 1.510153 | current accuracy 0.569800 || Test: accuracy 0.555700
# Iter 2:  Training: current loss 0.645434 | current accuracy 0.825000 || Validation: current loss 0.627609 | current accuracy 0.833600 || Test: accuracy 0.831500
# Iter 3:  Training: current loss 0.454882 | current accuracy 0.871255 || Validation: current loss 0.435064 | current accuracy 0.880200 || Test: accuracy 0.874000
# Iter 4:  Training: current loss 0.379940 | current accuracy 0.891855 || Validation: current loss 0.364220 | current accuracy 0.897800 || Test: accuracy 0.893700
# Iter 5:  Training: current loss 0.342947 | current accuracy 0.901382 || Validation: current loss 0.327551 | current accuracy 0.906800 || Test: accuracy 0.902600
# Iter 6:  Training: current loss 0.321313 | current accuracy 0.906182 || Validation: current loss 0.308932 | current accuracy 0.912600 || Test: accuracy 0.912200
# Iter 7:  Training: current loss 0.302535 | current accuracy 0.911509 || Validation: current loss 0.288540 | current accuracy 0.918000 || Test: accuracy 0.914000
# Iter 8:  Training: current loss 0.281630 | current accuracy 0.917564 || Validation: current loss 0.269410 | current accuracy 0.922800 || Test: accuracy 0.921300
# Iter 9:  Training: current loss 0.270971 | current accuracy 0.920327 || Validation: current loss 0.257261 | current accuracy 0.926000 || Test: accuracy 0.922300
# Iter 10:  Training: current loss 0.256195 | current accuracy 0.925527 || Validation: current loss 0.244232 | current accuracy 0.929000 || Test: accuracy 0.925000
# Iter 11:  Training: current loss 0.247060 | current accuracy 0.927455 || Validation: current loss 0.236549 | current accuracy 0.931200 || Test: accuracy 0.928200
# Iter 12:  Training: current loss 0.236965 | current accuracy 0.930418 || Validation: current loss 0.227952 | current accuracy 0.931600 || Test: accuracy 0.928900
# Iter 13:  Training: current loss 0.226696 | current accuracy 0.934473 || Validation: current loss 0.218001 | current accuracy 0.936800 || Test: accuracy 0.933700
# Iter 14:  Training: current loss 0.225868 | current accuracy 0.932036 || Validation: current loss 0.217341 | current accuracy 0.934000 || Test: accuracy 0.931100
# Iter 15:  Training: current loss 0.212390 | current accuracy 0.937855 || Validation: current loss 0.205929 | current accuracy 0.938600 || Test: accuracy 0.935600
# Iter 16:  Training: current loss 0.204300 | current accuracy 0.940673 || Validation: current loss 0.198243 | current accuracy 0.940600 || Test: accuracy 0.936100
# Iter 17:  Training: current loss 0.198657 | current accuracy 0.942491 || Validation: current loss 0.194071 | current accuracy 0.944400 || Test: accuracy 0.940100
# Iter 18:  Training: current loss 0.189426 | current accuracy 0.944618 || Validation: current loss 0.184928 | current accuracy 0.944600 || Test: accuracy 0.942100
# Iter 19:  Training: current loss 0.182564 | current accuracy 0.946582 || Validation: current loss 0.180673 | current accuracy 0.946600 || Test: accuracy 0.944200
# Iter 20:  Training: current loss 0.176877 | current accuracy 0.948309 || Validation: current loss 0.174941 | current accuracy 0.948800 || Test: accuracy 0.946600
# Iter 21:  Training: current loss 0.170187 | current accuracy 0.950236 || Validation: current loss 0.169225 | current accuracy 0.949200 || Test: accuracy 0.946900
# Iter 22:  Training: current loss 0.169885 | current accuracy 0.950218 || Validation: current loss 0.168356 | current accuracy 0.952200 || Test: accuracy 0.947400
# Iter 23:  Training: current loss 0.159542 | current accuracy 0.953127 || Validation: current loss 0.160089 | current accuracy 0.954000 || Test: accuracy 0.951100
# Iter 24:  Training: current loss 0.161109 | current accuracy 0.952091 || Validation: current loss 0.160591 | current accuracy 0.953000 || Test: accuracy 0.949300
# Iter 25:  Training: current loss 0.149643 | current accuracy 0.955818 || Validation: current loss 0.151658 | current accuracy 0.956200 || Test: accuracy 0.954100
# Iter 26:  Training: current loss 0.151160 | current accuracy 0.955709 || Validation: current loss 0.156018 | current accuracy 0.954800 || Test: accuracy 0.952900
# Iter 27:  Training: current loss 0.143895 | current accuracy 0.957727 || Validation: current loss 0.146375 | current accuracy 0.958200 || Test: accuracy 0.954400
# Iter 28:  Training: current loss 0.136715 | current accuracy 0.960255 || Validation: current loss 0.142253 | current accuracy 0.960600 || Test: accuracy 0.957100
# Iter 29:  Training: current loss 0.132201 | current accuracy 0.960818 || Validation: current loss 0.135445 | current accuracy 0.960800 || Test: accuracy 0.958400
# Iter 30:  Training: current loss 0.139982 | current accuracy 0.957764 || Validation: current loss 0.145766 | current accuracy 0.957200 || Test: accuracy 0.955000
# Iter 31:  Training: current loss 0.122941 | current accuracy 0.964491 || Validation: current loss 0.129872 | current accuracy 0.964000 || Test: accuracy 0.961600
# Iter 32:  Training: current loss 0.119569 | current accuracy 0.965291 || Validation: current loss 0.126568 | current accuracy 0.965400 || Test: accuracy 0.961100
# Iter 33:  Training: current loss 0.117806 | current accuracy 0.965109 || Validation: current loss 0.124084 | current accuracy 0.964400 || Test: accuracy 0.962100
# Iter 34:  Training: current loss 0.113886 | current accuracy 0.967200 || Validation: current loss 0.121490 | current accuracy 0.967600 || Test: accuracy 0.961800
# Iter 35:  Training: current loss 0.110876 | current accuracy 0.967455 || Validation: current loss 0.118793 | current accuracy 0.968200 || Test: accuracy 0.962600
# Iter 36:  Training: current loss 0.108892 | current accuracy 0.968436 || Validation: current loss 0.119636 | current accuracy 0.967800 || Test: accuracy 0.963100
# Iter 37:  Training: current loss 0.105496 | current accuracy 0.969527 || Validation: current loss 0.114899 | current accuracy 0.968800 || Test: accuracy 0.963900
# Iter 38:  Training: current loss 0.103583 | current accuracy 0.969855 || Validation: current loss 0.112255 | current accuracy 0.970400 || Test: accuracy 0.963000
# Iter 39:  Training: current loss 0.100163 | current accuracy 0.971145 || Validation: current loss 0.109843 | current accuracy 0.969000 || Test: accuracy 0.964700
# Iter 40:  Training: current loss 0.099910 | current accuracy 0.971091 || Validation: current loss 0.110276 | current accuracy 0.971600 || Test: accuracy 0.964300
# Iter 41:  Training: current loss 0.093793 | current accuracy 0.973364 || Validation: current loss 0.105563 | current accuracy 0.971000 || Test: accuracy 0.966900
# Iter 42:  Training: current loss 0.091782 | current accuracy 0.973436 || Validation: current loss 0.103999 | current accuracy 0.971800 || Test: accuracy 0.965400
# Iter 43:  Training: current loss 0.090439 | current accuracy 0.973709 || Validation: current loss 0.102604 | current accuracy 0.972400 || Test: accuracy 0.966900
# Iter 44:  Training: current loss 0.091185 | current accuracy 0.974309 || Validation: current loss 0.104032 | current accuracy 0.972200 || Test: accuracy 0.967600
# Iter 45:  Training: current loss 0.085185 | current accuracy 0.975509 || Validation: current loss 0.099975 | current accuracy 0.972600 || Test: accuracy 0.967600

# %%
dbn_model_2 = DeepBeliefNetwork(
        name='dbn',
        rbm_layers=[800, 400, 10],
        rbm_gauss_visible=True,
        finetune_num_epochs=80,
        do_pretrain=False)
accuracy_summary_2, loss_summary_2 = dbn_model_2.fit(train_dataset, train_labels, validation_dataset, validation_labels, test_dataset, test_labels)
# Out:
# Iter 1:  Training: current loss 2.192586 | current accuracy 0.266218 || Validation: current loss 2.189679 | current accuracy 0.267400 || Test: accuracy 0.264800
# Iter 2:  Training: current loss 1.337034 | current accuracy 0.567455 || Validation: current loss 1.320405 | current accuracy 0.574000 || Test: accuracy 0.564700
# Iter 3:  Training: current loss 0.906213 | current accuracy 0.753436 || Validation: current loss 0.888094 | current accuracy 0.757000 || Test: accuracy 0.757200
# Iter 4:  Training: current loss 0.646324 | current accuracy 0.831055 || Validation: current loss 0.632591 | current accuracy 0.838800 || Test: accuracy 0.837700
# Iter 5:  Training: current loss 0.538592 | current accuracy 0.851927 || Validation: current loss 0.528919 | current accuracy 0.855400 || Test: accuracy 0.859800
# Iter 6:  Training: current loss 0.452545 | current accuracy 0.878273 || Validation: current loss 0.442784 | current accuracy 0.884400 || Test: accuracy 0.880500
# Iter 7:  Training: current loss 0.408235 | current accuracy 0.887764 || Validation: current loss 0.397618 | current accuracy 0.891200 || Test: accuracy 0.890000
# Iter 8:  Training: current loss 0.376294 | current accuracy 0.894527 || Validation: current loss 0.365032 | current accuracy 0.897600 || Test: accuracy 0.897200
# Iter 9:  Training: current loss 0.353017 | current accuracy 0.901273 || Validation: current loss 0.342220 | current accuracy 0.907600 || Test: accuracy 0.902900
# Iter 10:  Training: current loss 0.337301 | current accuracy 0.905745 || Validation: current loss 0.324884 | current accuracy 0.909000 || Test: accuracy 0.907800
# Iter 11:  Training: current loss 0.318017 | current accuracy 0.910691 || Validation: current loss 0.307117 | current accuracy 0.915000 || Test: accuracy 0.913600
# Iter 12:  Training: current loss 0.302550 | current accuracy 0.913818 || Validation: current loss 0.290232 | current accuracy 0.918600 || Test: accuracy 0.915900
# Iter 13:  Training: current loss 0.287338 | current accuracy 0.919418 || Validation: current loss 0.276122 | current accuracy 0.921400 || Test: accuracy 0.921400
# Iter 14:  Training: current loss 0.284103 | current accuracy 0.918255 || Validation: current loss 0.270552 | current accuracy 0.923800 || Test: accuracy 0.917900
# Iter 15:  Training: current loss 0.256381 | current accuracy 0.928709 || Validation: current loss 0.246192 | current accuracy 0.930600 || Test: accuracy 0.927700
# Iter 16:  Training: current loss 0.248274 | current accuracy 0.930291 || Validation: current loss 0.239092 | current accuracy 0.932000 || Test: accuracy 0.929700
# Iter 17:  Training: current loss 0.250768 | current accuracy 0.927836 || Validation: current loss 0.242523 | current accuracy 0.929000 || Test: accuracy 0.928700
# Iter 18:  Training: current loss 0.221478 | current accuracy 0.938582 || Validation: current loss 0.213759 | current accuracy 0.938800 || Test: accuracy 0.937100
# Iter 19:  Training: current loss 0.213487 | current accuracy 0.939891 || Validation: current loss 0.205673 | current accuracy 0.943600 || Test: accuracy 0.938100
# Iter 20:  Training: current loss 0.202727 | current accuracy 0.943509 || Validation: current loss 0.198093 | current accuracy 0.946400 || Test: accuracy 0.942000
# Iter 21:  Training: current loss 0.204158 | current accuracy 0.941582 || Validation: current loss 0.201302 | current accuracy 0.943600 || Test: accuracy 0.938900
# Iter 22:  Training: current loss 0.194495 | current accuracy 0.945236 || Validation: current loss 0.193970 | current accuracy 0.945800 || Test: accuracy 0.942700
# Iter 23:  Training: current loss 0.175335 | current accuracy 0.951436 || Validation: current loss 0.174893 | current accuracy 0.950400 || Test: accuracy 0.947800
# Iter 24:  Training: current loss 0.169390 | current accuracy 0.952818 || Validation: current loss 0.169602 | current accuracy 0.952800 || Test: accuracy 0.949100
# Iter 25:  Training: current loss 0.166182 | current accuracy 0.952945 || Validation: current loss 0.166941 | current accuracy 0.951800 || Test: accuracy 0.950100
# Iter 26:  Training: current loss 0.155656 | current accuracy 0.955818 || Validation: current loss 0.158113 | current accuracy 0.957200 || Test: accuracy 0.952300
# Iter 27:  Training: current loss 0.158520 | current accuracy 0.954345 || Validation: current loss 0.162259 | current accuracy 0.952200 || Test: accuracy 0.951000
# Iter 28:  Training: current loss 0.144223 | current accuracy 0.959436 || Validation: current loss 0.149893 | current accuracy 0.958200 || Test: accuracy 0.954600
# Iter 29:  Training: current loss 0.147292 | current accuracy 0.957400 || Validation: current loss 0.152568 | current accuracy 0.954800 || Test: accuracy 0.951400
# Iter 30:  Training: current loss 0.139170 | current accuracy 0.960618 || Validation: current loss 0.146524 | current accuracy 0.958800 || Test: accuracy 0.955600
# Iter 31:  Training: current loss 0.133696 | current accuracy 0.961782 || Validation: current loss 0.140641 | current accuracy 0.959400 || Test: accuracy 0.954700
# Iter 32:  Training: current loss 0.127694 | current accuracy 0.963582 || Validation: current loss 0.135156 | current accuracy 0.961200 || Test: accuracy 0.957200
# Iter 33:  Training: current loss 0.121179 | current accuracy 0.965964 || Validation: current loss 0.131264 | current accuracy 0.963600 || Test: accuracy 0.958500
# Iter 34:  Training: current loss 0.115638 | current accuracy 0.968109 || Validation: current loss 0.126203 | current accuracy 0.966000 || Test: accuracy 0.960200
# Iter 35:  Training: current loss 0.116505 | current accuracy 0.966745 || Validation: current loss 0.125866 | current accuracy 0.963200 || Test: accuracy 0.960500
# Iter 36:  Training: current loss 0.118714 | current accuracy 0.965455 || Validation: current loss 0.131697 | current accuracy 0.960800 || Test: accuracy 0.960000
# Iter 37:  Training: current loss 0.111026 | current accuracy 0.969200 || Validation: current loss 0.127022 | current accuracy 0.965200 || Test: accuracy 0.960500
# Iter 38:  Training: current loss 0.115171 | current accuracy 0.967291 || Validation: current loss 0.129247 | current accuracy 0.964400 || Test: accuracy 0.960400
# Iter 39:  Training: current loss 0.099241 | current accuracy 0.972673 || Validation: current loss 0.117601 | current accuracy 0.967600 || Test: accuracy 0.964600
# Iter 40:  Training: current loss 0.100017 | current accuracy 0.971600 || Validation: current loss 0.116138 | current accuracy 0.967800 || Test: accuracy 0.962100
# Iter 41:  Training: current loss 0.102378 | current accuracy 0.970855 || Validation: current loss 0.123383 | current accuracy 0.966000 || Test: accuracy 0.963500
# Iter 42:  Training: current loss 0.094223 | current accuracy 0.973800 || Validation: current loss 0.115462 | current accuracy 0.969600 || Test: accuracy 0.965000
# Iter 43:  Training: current loss 0.088338 | current accuracy 0.976164 || Validation: current loss 0.109647 | current accuracy 0.969600 || Test: accuracy 0.965500
# Iter 44:  Training: current loss 0.091439 | current accuracy 0.974473 || Validation: current loss 0.114950 | current accuracy 0.968200 || Test: accuracy 0.964800
# Iter 45:  Training: current loss 0.084036 | current accuracy 0.977455 || Validation: current loss 0.109722 | current accuracy 0.970600 || Test: accuracy 0.968600
# Iter 46:  Training: current loss 0.078897 | current accuracy 0.978455 || Validation: current loss 0.101655 | current accuracy 0.972200 || Test: accuracy 0.969400
# Iter 47:  Training: current loss 0.077428 | current accuracy 0.979436 || Validation: current loss 0.100339 | current accuracy 0.972200 || Test: accuracy 0.968600
# Iter 48:  Training: current loss 0.077719 | current accuracy 0.978491 || Validation: current loss 0.101125 | current accuracy 0.973600 || Test: accuracy 0.969300
# Iter 49:  Training: current loss 0.079164 | current accuracy 0.978782 || Validation: current loss 0.106480 | current accuracy 0.970000 || Test: accuracy 0.968000
# Iter 50:  Training: current loss 0.074578 | current accuracy 0.980255 || Validation: current loss 0.099279 | current accuracy 0.971200 || Test: accuracy 0.970100
# Iter 51:  Training: current loss 0.072780 | current accuracy 0.980418 || Validation: current loss 0.097978 | current accuracy 0.972000 || Test: accuracy 0.969400
# Iter 52:  Training: current loss 0.067040 | current accuracy 0.982327 || Validation: current loss 0.097231 | current accuracy 0.973800 || Test: accuracy 0.969700
# Iter 53:  Training: current loss 0.065547 | current accuracy 0.982782 || Validation: current loss 0.093491 | current accuracy 0.974200 || Test: accuracy 0.971200
# Iter 54:  Training: current loss 0.065783 | current accuracy 0.983018 || Validation: current loss 0.097067 | current accuracy 0.972800 || Test: accuracy 0.969700
# Iter 55:  Training: current loss 0.063394 | current accuracy 0.983345 || Validation: current loss 0.093456 | current accuracy 0.974000 || Test: accuracy 0.972100
# Iter 56:  Training: current loss 0.067280 | current accuracy 0.981891 || Validation: current loss 0.097931 | current accuracy 0.974400 || Test: accuracy 0.969500
# Iter 57:  Training: current loss 0.061716 | current accuracy 0.983764 || Validation: current loss 0.094336 | current accuracy 0.974200 || Test: accuracy 0.971700
# Iter 58:  Training: current loss 0.058011 | current accuracy 0.985036 || Validation: current loss 0.091365 | current accuracy 0.973000 || Test: accuracy 0.971700

# %%
dbn_model_3 = DeepBeliefNetwork(
        name='dbn',
        rbm_layers=[800, 400, 5],
        rbm_gauss_visible=True,
        finetune_num_epochs=300,
        do_pretrain=False)
accuracy_summary_3, loss_summary_3 = dbn_model_3.fit(train_dataset, train_labels, validation_dataset, validation_labels, test_dataset, test_labels)
# Out:
# Iter 1:  Training: current loss 2.286309 | current accuracy 0.112345 || Validation: current loss 2.285796 | current accuracy 0.112600 || Test: accuracy 0.113500
# Iter 2:  Training: current loss 1.809837 | current accuracy 0.350800 || Validation: current loss 1.800493 | current accuracy 0.355400 || Test: accuracy 0.349200
# Iter 3:  Training: current loss 1.331861 | current accuracy 0.582000 || Validation: current loss 1.322262 | current accuracy 0.580600 || Test: accuracy 0.593800
# Iter 4:  Training: current loss 0.990252 | current accuracy 0.681964 || Validation: current loss 0.973336 | current accuracy 0.694600 || Test: accuracy 0.692300
# Iter 5:  Training: current loss 0.807223 | current accuracy 0.760909 || Validation: current loss 0.787207 | current accuracy 0.775000 || Test: accuracy 0.772000
# Iter 6:  Training: current loss 0.713278 | current accuracy 0.783182 || Validation: current loss 0.694157 | current accuracy 0.791400 || Test: accuracy 0.793100
# Iter 7:  Training: current loss 0.610763 | current accuracy 0.828855 || Validation: current loss 0.593097 | current accuracy 0.837600 || Test: accuracy 0.833200
# Iter 8:  Training: current loss 0.554102 | current accuracy 0.847109 || Validation: current loss 0.535915 | current accuracy 0.856800 || Test: accuracy 0.852000
# Iter 9:  Training: current loss 0.487695 | current accuracy 0.868709 || Validation: current loss 0.473051 | current accuracy 0.875600 || Test: accuracy 0.872000
# Iter 10:  Training: current loss 0.447616 | current accuracy 0.881509 || Validation: current loss 0.431487 | current accuracy 0.891600 || Test: accuracy 0.883700
# Iter 11:  Training: current loss 0.418125 | current accuracy 0.886891 || Validation: current loss 0.402706 | current accuracy 0.893000 || Test: accuracy 0.888100
# Iter 12:  Training: current loss 0.373992 | current accuracy 0.902364 || Validation: current loss 0.361336 | current accuracy 0.909400 || Test: accuracy 0.899300
# Iter 13:  Training: current loss 0.356500 | current accuracy 0.906127 || Validation: current loss 0.346094 | current accuracy 0.910200 || Test: accuracy 0.905300
# Iter 14:  Training: current loss 0.319248 | current accuracy 0.918327 || Validation: current loss 0.311960 | current accuracy 0.918600 || Test: accuracy 0.915400
# Iter 15:  Training: current loss 0.307238 | current accuracy 0.920055 || Validation: current loss 0.301335 | current accuracy 0.920600 || Test: accuracy 0.916600
# Iter 16:  Training: current loss 0.277782 | current accuracy 0.929182 || Validation: current loss 0.271436 | current accuracy 0.933800 || Test: accuracy 0.925100
# Iter 17:  Training: current loss 0.264196 | current accuracy 0.932000 || Validation: current loss 0.259795 | current accuracy 0.935800 || Test: accuracy 0.928200
# Iter 18:  Training: current loss 0.259746 | current accuracy 0.933127 || Validation: current loss 0.255164 | current accuracy 0.936600 || Test: accuracy 0.929300
# Iter 19:  Training: current loss 0.232767 | current accuracy 0.939709 || Validation: current loss 0.231127 | current accuracy 0.940200 || Test: accuracy 0.935900
# Iter 20:  Training: current loss 0.232754 | current accuracy 0.937255 || Validation: current loss 0.231931 | current accuracy 0.937600 || Test: accuracy 0.934600
# Iter 21:  Training: current loss 0.203363 | current accuracy 0.947564 || Validation: current loss 0.202608 | current accuracy 0.947600 || Test: accuracy 0.942200
# Iter 22:  Training: current loss 0.212929 | current accuracy 0.945255 || Validation: current loss 0.214765 | current accuracy 0.943800 || Test: accuracy 0.939100
# Iter 23:  Training: current loss 0.188878 | current accuracy 0.950455 || Validation: current loss 0.191589 | current accuracy 0.949400 || Test: accuracy 0.944700
# Iter 24:  Training: current loss 0.176377 | current accuracy 0.955255 || Validation: current loss 0.180962 | current accuracy 0.953600 || Test: accuracy 0.949400
# Iter 25:  Training: current loss 0.168191 | current accuracy 0.956618 || Validation: current loss 0.171961 | current accuracy 0.957000 || Test: accuracy 0.949900
# Iter 26:  Training: current loss 0.173020 | current accuracy 0.954127 || Validation: current loss 0.177018 | current accuracy 0.954800 || Test: accuracy 0.946500
# Iter 27:  Training: current loss 0.165675 | current accuracy 0.956218 || Validation: current loss 0.171802 | current accuracy 0.955000 || Test: accuracy 0.949600
# Iter 28:  Training: current loss 0.151993 | current accuracy 0.960327 || Validation: current loss 0.160013 | current accuracy 0.956200 || Test: accuracy 0.955300
# Iter 29:  Training: current loss 0.141323 | current accuracy 0.963073 || Validation: current loss 0.150395 | current accuracy 0.960000 || Test: accuracy 0.956200
# Iter 30:  Training: current loss 0.170275 | current accuracy 0.951582 || Validation: current loss 0.178746 | current accuracy 0.947400 || Test: accuracy 0.945600
# Iter 31:  Training: current loss 0.140684 | current accuracy 0.961873 || Validation: current loss 0.150252 | current accuracy 0.958600 || Test: accuracy 0.955400
# Iter 32:  Training: current loss 0.138380 | current accuracy 0.963236 || Validation: current loss 0.151667 | current accuracy 0.961800 || Test: accuracy 0.956500
# Iter 33:  Training: current loss 0.135173 | current accuracy 0.964127 || Validation: current loss 0.148509 | current accuracy 0.959600 || Test: accuracy 0.957200
# Iter 34:  Training: current loss 0.118493 | current accuracy 0.968836 || Validation: current loss 0.132472 | current accuracy 0.965600 || Test: accuracy 0.960900
# Iter 35:  Training: current loss 0.125443 | current accuracy 0.967418 || Validation: current loss 0.144221 | current accuracy 0.960800 || Test: accuracy 0.960000
# Iter 36:  Training: current loss 0.111135 | current accuracy 0.971327 || Validation: current loss 0.127494 | current accuracy 0.966400 || Test: accuracy 0.963100
# Iter 37:  Training: current loss 0.112561 | current accuracy 0.970709 || Validation: current loss 0.128978 | current accuracy 0.964800 || Test: accuracy 0.964200
# Iter 38:  Training: current loss 0.107374 | current accuracy 0.971655 || Validation: current loss 0.127262 | current accuracy 0.965600 || Test: accuracy 0.963200
# Iter 39:  Training: current loss 0.098897 | current accuracy 0.974636 || Validation: current loss 0.120140 | current accuracy 0.966200 || Test: accuracy 0.966200
# Iter 40:  Training: current loss 0.098849 | current accuracy 0.974273 || Validation: current loss 0.119427 | current accuracy 0.969600 || Test: accuracy 0.966100
# Iter 41:  Training: current loss 0.092602 | current accuracy 0.976673 || Validation: current loss 0.116171 | current accuracy 0.969400 || Test: accuracy 0.967500
# Iter 42:  Training: current loss 0.091599 | current accuracy 0.977345 || Validation: current loss 0.117018 | current accuracy 0.969800 || Test: accuracy 0.967200
# Iter 43:  Training: current loss 0.092917 | current accuracy 0.976673 || Validation: current loss 0.120347 | current accuracy 0.968800 || Test: accuracy 0.967300
# Iter 44:  Training: current loss 0.094023 | current accuracy 0.974455 || Validation: current loss 0.122168 | current accuracy 0.967800 || Test: accuracy 0.966000
# Iter 45:  Training: current loss 0.094132 | current accuracy 0.974327 || Validation: current loss 0.122610 | current accuracy 0.964200 || Test: accuracy 0.963000
# Iter 46:  Training: current loss 0.082188 | current accuracy 0.979673 || Validation: current loss 0.111353 | current accuracy 0.968000 || Test: accuracy 0.969100
# Iter 47:  Training: current loss 0.085393 | current accuracy 0.977109 || Validation: current loss 0.111726 | current accuracy 0.967600 || Test: accuracy 0.966000
# Iter 48:  Training: current loss 0.076375 | current accuracy 0.981345 || Validation: current loss 0.106944 | current accuracy 0.969800 || Test: accuracy 0.971200
# Iter 49:  Training: current loss 0.082144 | current accuracy 0.979873 || Validation: current loss 0.113696 | current accuracy 0.971800 || Test: accuracy 0.967700
# Iter 50:  Training: current loss 0.074450 | current accuracy 0.981836 || Validation: current loss 0.107676 | current accuracy 0.969200 || Test: accuracy 0.968800
# Iter 51:  Training: current loss 0.069836 | current accuracy 0.982818 || Validation: current loss 0.103329 | current accuracy 0.971600 || Test: accuracy 0.970200
# Iter 52:  Training: current loss 0.068267 | current accuracy 0.982818 || Validation: current loss 0.100333 | current accuracy 0.971400 || Test: accuracy 0.969600
# Iter 53:  Training: current loss 0.066844 | current accuracy 0.983691 || Validation: current loss 0.099539 | current accuracy 0.970800 || Test: accuracy 0.970800
# Iter 54:  Training: current loss 0.078978 | current accuracy 0.978055 || Validation: current loss 0.111867 | current accuracy 0.967800 || Test: accuracy 0.967500
# Iter 55:  Training: current loss 0.069542 | current accuracy 0.982273 || Validation: current loss 0.107311 | current accuracy 0.968600 || Test: accuracy 0.968900
# Iter 56:  Training: current loss 0.066124 | current accuracy 0.984309 || Validation: current loss 0.106064 | current accuracy 0.970800 || Test: accuracy 0.971000
# Iter 57:  Training: current loss 0.059605 | current accuracy 0.985673 || Validation: current loss 0.100003 | current accuracy 0.972800 || Test: accuracy 0.971200
# Iter 58:  Training: current loss 0.064394 | current accuracy 0.983855 || Validation: current loss 0.105401 | current accuracy 0.968000 || Test: accuracy 0.968600
# Iter 59:  Training: current loss 0.058770 | current accuracy 0.986182 || Validation: current loss 0.099437 | current accuracy 0.972600 || Test: accuracy 0.972800
# Iter 60:  Training: current loss 0.057293 | current accuracy 0.986145 || Validation: current loss 0.098815 | current accuracy 0.970600 || Test: accuracy 0.969900
# Iter 61:  Training: current loss 0.054560 | current accuracy 0.987182 || Validation: current loss 0.095874 | current accuracy 0.973800 || Test: accuracy 0.973300
# Iter 62:  Training: current loss 0.052674 | current accuracy 0.988018 || Validation: current loss 0.097968 | current accuracy 0.971000 || Test: accuracy 0.972300
# Iter 63:  Training: current loss 0.052427 | current accuracy 0.987545 || Validation: current loss 0.095533 | current accuracy 0.972800 || Test: accuracy 0.972800
# Iter 64:  Training: current loss 0.062436 | current accuracy 0.983145 || Validation: current loss 0.107304 | current accuracy 0.972600 || Test: accuracy 0.970000
# Iter 65:  Training: current loss 0.052436 | current accuracy 0.987309 || Validation: current loss 0.099684 | current accuracy 0.971000 || Test: accuracy 0.970400
# Iter 66:  Training: current loss 0.049360 | current accuracy 0.988109 || Validation: current loss 0.094443 | current accuracy 0.974600 || Test: accuracy 0.972500
# Iter 67:  Training: current loss 0.056213 | current accuracy 0.984982 || Validation: current loss 0.102755 | current accuracy 0.973200 || Test: accuracy 0.970900
# Iter 68:  Training: current loss 0.044363 | current accuracy 0.989964 || Validation: current loss 0.091069 | current accuracy 0.974400 || Test: accuracy 0.974400
# Iter 69:  Training: current loss 0.043057 | current accuracy 0.990564 || Validation: current loss 0.090957 | current accuracy 0.974600 || Test: accuracy 0.974700
# Iter 70:  Training: current loss 0.041389 | current accuracy 0.991164 || Validation: current loss 0.090929 | current accuracy 0.974400 || Test: accuracy 0.973300
# Iter 71:  Training: current loss 0.046948 | current accuracy 0.988927 || Validation: current loss 0.096764 | current accuracy 0.970800 || Test: accuracy 0.972000
# Iter 72:  Training: current loss 0.038941 | current accuracy 0.991691 || Validation: current loss 0.089345 | current accuracy 0.973400 || Test: accuracy 0.974400
# Iter 73:  Training: current loss 0.041842 | current accuracy 0.990236 || Validation: current loss 0.092074 | current accuracy 0.973600 || Test: accuracy 0.973300
# Iter 74:  Training: current loss 0.049649 | current accuracy 0.987855 || Validation: current loss 0.101947 | current accuracy 0.973400 || Test: accuracy 0.970000
# Iter 75:  Training: current loss 0.043380 | current accuracy 0.989582 || Validation: current loss 0.096915 | current accuracy 0.972600 || Test: accuracy 0.971300
# Iter 76:  Training: current loss 0.035650 | current accuracy 0.992709 || Validation: current loss 0.088275 | current accuracy 0.974800 || Test: accuracy 0.973400
# Iter 77:  Training: current loss 0.034712 | current accuracy 0.993182 || Validation: current loss 0.087769 | current accuracy 0.974400 || Test: accuracy 0.974300
# Iter 78:  Training: current loss 0.036494 | current accuracy 0.991727 || Validation: current loss 0.087474 | current accuracy 0.972800 || Test: accuracy 0.973700
# Iter 79:  Training: current loss 0.032572 | current accuracy 0.993600 || Validation: current loss 0.086823 | current accuracy 0.975800 || Test: accuracy 0.974100
# Iter 80:  Training: current loss 0.033979 | current accuracy 0.993182 || Validation: current loss 0.089809 | current accuracy 0.975200 || Test: accuracy 0.974300
# Iter 81:  Training: current loss 0.034526 | current accuracy 0.992600 || Validation: current loss 0.092152 | current accuracy 0.975800 || Test: accuracy 0.973700
# Iter 82:  Training: current loss 0.036529 | current accuracy 0.991636 || Validation: current loss 0.088394 | current accuracy 0.975200 || Test: accuracy 0.974500
# Iter 83:  Training: current loss 0.034404 | current accuracy 0.992109 || Validation: current loss 0.088660 | current accuracy 0.974400 || Test: accuracy 0.973200
# Iter 84:  Training: current loss 0.029021 | current accuracy 0.994400 || Validation: current loss 0.085520 | current accuracy 0.975400 || Test: accuracy 0.975400
# Iter 85:  Training: current loss 0.030866 | current accuracy 0.993673 || Validation: current loss 0.087720 | current accuracy 0.975200 || Test: accuracy 0.974200
# Iter 86:  Training: current loss 0.027722 | current accuracy 0.994836 || Validation: current loss 0.086284 | current accuracy 0.976200 || Test: accuracy 0.975400
# Iter 87:  Training: current loss 0.025840 | current accuracy 0.995600 || Validation: current loss 0.083069 | current accuracy 0.976600 || Test: accuracy 0.976400
# Iter 88:  Training: current loss 0.024847 | current accuracy 0.996145 || Validation: current loss 0.083797 | current accuracy 0.974600 || Test: accuracy 0.976500
# Iter 89:  Training: current loss 0.024981 | current accuracy 0.995745 || Validation: current loss 0.083854 | current accuracy 0.976200 || Test: accuracy 0.975700
# Iter 90:  Training: current loss 0.026040 | current accuracy 0.995309 || Validation: current loss 0.086238 | current accuracy 0.974800 || Test: accuracy 0.975800
# Iter 91:  Training: current loss 0.025592 | current accuracy 0.995164 || Validation: current loss 0.085593 | current accuracy 0.976400 || Test: accuracy 0.975300
# Iter 92:  Training: current loss 0.025776 | current accuracy 0.995255 || Validation: current loss 0.087317 | current accuracy 0.974600 || Test: accuracy 0.974700
# Iter 93:  Training: current loss 0.023942 | current accuracy 0.995800 || Validation: current loss 0.083436 | current accuracy 0.977000 || Test: accuracy 0.974900
# Iter 94:  Training: current loss 0.024055 | current accuracy 0.995673 || Validation: current loss 0.088289 | current accuracy 0.976400 || Test: accuracy 0.974700
# Iter 95:  Training: current loss 0.023179 | current accuracy 0.995455 || Validation: current loss 0.085963 | current accuracy 0.977600 || Test: accuracy 0.975400
# Iter 96:  Training: current loss 0.021858 | current accuracy 0.996018 || Validation: current loss 0.085045 | current accuracy 0.977000 || Test: accuracy 0.976200
# Iter 97:  Training: current loss 0.020652 | current accuracy 0.996800 || Validation: current loss 0.083301 | current accuracy 0.975200 || Test: accuracy 0.975100
# Iter 98:  Training: current loss 0.023454 | current accuracy 0.995600 || Validation: current loss 0.090594 | current accuracy 0.975400 || Test: accuracy 0.974100
# Iter 99:  Training: current loss 0.019613 | current accuracy 0.997327 || Validation: current loss 0.081975 | current accuracy 0.977600 || Test: accuracy 0.976900
# Iter 100:  Training: current loss 0.019751 | current accuracy 0.996927 || Validation: current loss 0.084533 | current accuracy 0.977000 || Test: accuracy 0.976400
# Iter 101:  Training: current loss 0.019377 | current accuracy 0.997127 || Validation: current loss 0.081907 | current accuracy 0.975400 || Test: accuracy 0.975800
# Iter 102:  Training: current loss 0.019641 | current accuracy 0.996745 || Validation: current loss 0.083128 | current accuracy 0.976600 || Test: accuracy 0.975500
# Iter 103:  Training: current loss 0.018182 | current accuracy 0.997000 || Validation: current loss 0.082052 | current accuracy 0.974600 || Test: accuracy 0.975300
# Iter 104:  Training: current loss 0.017799 | current accuracy 0.997382 || Validation: current loss 0.081512 | current accuracy 0.976200 || Test: accuracy 0.975600
# Iter 105:  Training: current loss 0.017409 | current accuracy 0.997491 || Validation: current loss 0.084125 | current accuracy 0.977200 || Test: accuracy 0.975900
# Iter 106:  Training: current loss 0.016545 | current accuracy 0.997636 || Validation: current loss 0.083966 | current accuracy 0.975800 || Test: accuracy 0.976100
# Iter 107:  Training: current loss 0.017655 | current accuracy 0.997236 || Validation: current loss 0.084195 | current accuracy 0.977400 || Test: accuracy 0.976800
# Iter 108:  Training: current loss 0.016356 | current accuracy 0.997636 || Validation: current loss 0.080205 | current accuracy 0.978800 || Test: accuracy 0.975300
# Iter 109:  Training: current loss 0.018343 | current accuracy 0.996891 || Validation: current loss 0.083868 | current accuracy 0.977600 || Test: accuracy 0.976000
# Iter 110:  Training: current loss 0.015716 | current accuracy 0.997927 || Validation: current loss 0.081046 | current accuracy 0.977800 || Test: accuracy 0.976500
# Iter 111:  Training: current loss 0.015168 | current accuracy 0.998018 || Validation: current loss 0.080697 | current accuracy 0.976600 || Test: accuracy 0.975600
# Iter 112:  Training: current loss 0.014176 | current accuracy 0.998273 || Validation: current loss 0.079268 | current accuracy 0.978800 || Test: accuracy 0.976000
# Iter 113:  Training: current loss 0.021604 | current accuracy 0.995400 || Validation: current loss 0.089121 | current accuracy 0.974200 || Test: accuracy 0.972500
# Iter 114:  Training: current loss 0.013388 | current accuracy 0.998273 || Validation: current loss 0.078674 | current accuracy 0.978600 || Test: accuracy 0.976600
# Iter 115:  Training: current loss 0.013258 | current accuracy 0.998436 || Validation: current loss 0.079548 | current accuracy 0.977600 || Test: accuracy 0.976200
# Iter 116:  Training: current loss 0.015281 | current accuracy 0.997727 || Validation: current loss 0.085155 | current accuracy 0.975600 || Test: accuracy 0.974700
# Iter 117:  Training: current loss 0.014260 | current accuracy 0.997964 || Validation: current loss 0.082247 | current accuracy 0.976200 || Test: accuracy 0.976800
# Iter 118:  Training: current loss 0.014113 | current accuracy 0.998000 || Validation: current loss 0.083315 | current accuracy 0.977800 || Test: accuracy 0.976500
# Iter 119:  Training: current loss 0.016311 | current accuracy 0.997455 || Validation: current loss 0.089632 | current accuracy 0.975400 || Test: accuracy 0.975400
# Iter 120:  Training: current loss 0.012358 | current accuracy 0.998436 || Validation: current loss 0.081638 | current accuracy 0.978600 || Test: accuracy 0.976300
# Iter 121:  Training: current loss 0.015440 | current accuracy 0.997491 || Validation: current loss 0.088081 | current accuracy 0.977200 || Test: accuracy 0.975100
# Iter 122:  Training: current loss 0.012496 | current accuracy 0.998436 || Validation: current loss 0.083032 | current accuracy 0.976800 || Test: accuracy 0.975000
# Iter 123:  Training: current loss 0.011129 | current accuracy 0.998745 || Validation: current loss 0.081205 | current accuracy 0.977800 || Test: accuracy 0.976700
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-dda8b254e1ea> in <module>()
#       5         finetune_num_epochs=300,
#       6         do_pretrain=False)
# ----> 7 accuracy_summary_3, loss_summary_3 = dbn_model_3.fit(train_dataset, train_labels, validation_dataset, validation_labels, test_dataset, test_labels)
#
# /Users/sq/Documents/projects/projet3A/notebooks/dbn.py in fit(self, train_set, train_labels, validation_set, validation_labels, test_set, test_labels, graph)
#     292                         validation_labels,
#     293                         test_set,
# --> 294                         test_labels)
#     295         return self.accuracy_summary, self.loss_summary
#     296
#
# /Users/sq/Documents/projects/projet3A/notebooks/dbn.py in _train_model(self, train_X, train_y, validation_X, validation_y, test_X, test_y)
#     325                         self.input_labels: y_batch,
#     326                         self.keep_prob: self.finetune_dropout}
# --> 327                 self.sess.run(self.train_step, feed_dict=feed_batch)
#     328
#     329             updates = [self.loss, self.accuracy]
#
# /usr/local/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /usr/local/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
